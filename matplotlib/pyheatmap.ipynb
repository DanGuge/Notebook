# %%
from pyheatmap.heatmap import HeatMap
import numpy as np
N = 100
X = np.random.rand(N) * 255  # [0, 255]
Y = np.random.rand(N) * 255
data = []
for i in range(N):
  tmp = [int(X[i]), int(Y[i]), 1]
  data.append(tmp)
heat = HeatMap(data)
heat.clickmap() #点击图
heat.heatmap() #热图
# Out:
# <PIL.Image.Image image mode=RGBA size=255x252 at 0x7F93A6EC2940>
